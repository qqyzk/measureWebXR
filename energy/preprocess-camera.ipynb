# %%
import pandas as pd
import os
from perfetto.trace_processor import TraceProcessor, TraceProcessorConfig
import matplotlib.pyplot as plt

# %%
frameworks = ['three','babylon','playcanvas','aframe','rtf','ar-three','ar-aframe','mindar-three','mindar-aframe']
cubeNums = [8,64,512,4096,32768]
textureNums =[0,1,2,4]
railNames = ['power.rails.aoc.logic',
            'power.rails.aoc.memory',
            'power.rails.cpu.big',
            'power.rails.cpu.little',
            'power.rails.cpu.mid',
            'power.rails.ddr.a',
            'power.rails.ddr.b',
            'power.rails.ddr.c',
            'power.rails.display',
            'power.rails.gpu',
            'power.rails.memory.interface',
            'power.rails.modem',
            'power.rails.radio.frontend',
            'power.rails.system.fabric',
            'power.rails.tpu',
            'power.rails.wifi.bt']

# %%
def getEnergy(filename):
    config = TraceProcessorConfig(verbose=True,bin_path='./trace_processor')
    tp = TraceProcessor(trace=filename,config=config)
    qr_it = tp.query('select ts, counter_track.name, value  from counter left join counter_track where counter_track.id=counter.track_id')
    qr_df = qr_it.as_pandas_dataframe()
    power_df = qr_df[qr_df['name'].str[:5] == 'power']
    power_df = power_df.drop_duplicates()
    total_mean_ratio = 0
    name_mean_ratio = {}
    for i, name in enumerate(railNames):
        data = power_df[power_df['name'] == name]
        diffs = data['value'].diff()
        time_diffs = data['ts'].diff()
        data['ratio'] =  diffs / time_diffs*1000
        data = data.dropna()
        mean_ratio = data['ratio'].mean()
        name_mean_ratio[name] = mean_ratio
        total_mean_ratio += mean_ratio
    name_mean_ratio['total'] = total_mean_ratio
    return name_mean_ratio

# %%
with open ('./results/pixel-camera-energy.csv','w') as f:
    f.write('framework,textureNum,cubeNum,total')
    for rail in railNames:
        f.write(','+rail)
    f.write('\n')
    for framework in frameworks:
        for textureNum in textureNums:
            for cubeNum in cubeNums:
                filename = './results/pixel/trace-'+framework+'-camera-'+str(textureNum)+'-'+str(cubeNum)
                print(filename)
                if not os.path.exists(filename):
                    continue
                energyData = getEnergy(filename)
                f.write(framework+','+str(textureNum)+','+str(cubeNum)+','+str(energyData['total']))
                for rail in railNames:
                    f.write(','+str(energyData[rail]))
                f.write('\n')
# Out:
# ./results/pixel/trace-three-camera-0-8
# [998.120]             httpd.cc:99 [HTTP] Starting RPC server on localhost:49361
# [998.120]            httpd.cc:104 [HTTP] This server can be used by reloading https://ui.perfetto.dev and clicking on YES on the "Trace Processor native acceleration" dialog or through the Python API (see https://perfetto.dev/docs/analysis/trace-processor#python-api).
# [999.064]       http_server.cc:83 [HTTP] New connection
# [999.064]      http_server.cc:231 [HTTP] GET /status [body=0B, origin=""]
# [999.064]       http_server.cc:90 [HTTP] Client disconnected
# [999.066]       http_server.cc:83 [HTTP] New connection
# [999.067]      http_server.cc:231 [HTTP] POST /parse [body=104344B, origin=""]
# [999.069]      http_server.cc:231 [HTTP] GET /notify_eof [body=0B, origin=""]
# Loading trace 0.10 MB (0.0 MB/s)
# [999.076]      http_server.cc:231 [HTTP] POST /query [body=116B, origin=""]
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# [999.154]             httpd.cc:99 [HTTP] Starting RPC server on localhost:49378
# [999.154]            httpd.cc:104 [HTTP] This server can be used by reloading https://ui.perfetto.dev and clicking on YES on the "Trace Processor native acceleration" dialog or through the Python API (see https://perfetto.dev/docs/analysis/trace-processor#python-api).
# ./results/pixel/trace-three-camera-0-64
# [000.123]       http_server.cc:83 [HTTP] New connection
# [000.124]      http_server.cc:231 [HTTP] GET /status [body=0B, origin=""]
# [000.124]       http_server.cc:90 [HTTP] Client disconnected
# [000.128]       http_server.cc:83 [HTTP] New connection
# [000.128]      http_server.cc:231 [HTTP] POST /parse [body=104455B, origin=""]
# [000.135]      http_server.cc:231 [HTTP] GET /notify_eof [body=0B, origin=""]
# Loading trace 0.10 MB (0.0 MB/s)
# [000.148]      http_server.cc:231 [HTTP] POST /query [body=116B, origin=""]
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# [000.244]             httpd.cc:99 [HTTP] Starting RPC server on localhost:49395
# [000.244]            httpd.cc:104 [HTTP] This server can be used by reloading https://ui.perfetto.dev and clicking on YES on the "Trace Processor native acceleration" dialog or through the Python API (see https://perfetto.dev/docs/analysis/trace-processor#python-api).
# ./results/pixel/trace-three-camera-0-512
# [001.212]       http_server.cc:83 [HTTP] New connection
# [001.212]      http_server.cc:231 [HTTP] GET /status [body=0B, origin=""]
# [001.213]       http_server.cc:90 [HTTP] Client disconnected
# [001.217]       http_server.cc:83 [HTTP] New connection
# [001.217]      http_server.cc:231 [HTTP] POST /parse [body=104504B, origin=""]
# [001.222]      http_server.cc:231 [HTTP] GET /notify_eof [body=0B, origin=""]
# Loading trace 0.10 MB (0.0 MB/s)
# [001.236]      http_server.cc:231 [HTTP] POST /query [body=116B, origin=""]
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# [001.330]             httpd.cc:99 [HTTP] Starting RPC server on localhost:49413
# [001.330]            httpd.cc:104 [HTTP] This server can be used by reloading https://ui.perfetto.dev and clicking on YES on the "Trace Processor native acceleration" dialog or through the Python API (see https://perfetto.dev/docs/analysis/trace-processor#python-api).
# ./results/pixel/trace-three-camera-0-4096
# [002.294]       http_server.cc:83 [HTTP] New connection
# [002.294]      http_server.cc:231 [HTTP] GET /status [body=0B, origin=""]
# [002.294]       http_server.cc:90 [HTTP] Client disconnected
# [002.297]       http_server.cc:83 [HTTP] New connection
# [002.297]      http_server.cc:231 [HTTP] POST /parse [body=104092B, origin=""]
# [002.299]      http_server.cc:231 [HTTP] GET /notify_eof [body=0B, origin=""]
# Loading trace 0.10 MB (0.0 MB/s)
# [002.305]      http_server.cc:231 [HTTP] POST /query [body=116B, origin=""]
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# [002.408]             httpd.cc:99 [HTTP] Starting RPC server on localhost:49440
# [002.408]            httpd.cc:104 [HTTP] This server can be used by reloading https://ui.perfetto.dev and clicking on YES on the "Trace Processor native acceleration" dialog or through the Python API (see https://perfetto.dev/docs/analysis/trace-processor#python-api).
# ./results/pixel/trace-three-camera-0-32768
# [003.354]       http_server.cc:83 [HTTP] New connection
# [003.354]      http_server.cc:231 [HTTP] GET /status [body=0B, origin=""]
# [003.354]       http_server.cc:90 [HTTP] Client disconnected
# [003.356]       http_server.cc:83 [HTTP] New connection
# [003.356]      http_server.cc:231 [HTTP] POST /parse [body=104471B, origin=""]
# [003.359]      http_server.cc:231 [HTTP] GET /notify_eof [body=0B, origin=""]
# Loading trace 0.10 MB (0.0 MB/s)
# [003.366]      http_server.cc:231 [HTTP] POST /query [body=116B, origin=""]
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# [003.446]             httpd.cc:99 [HTTP] Starting RPC server on localhost:49457
# [003.446]            httpd.cc:104 [HTTP] This server can be used by reloading https://ui.perfetto.dev and clicking on YES on the "Trace Processor native acceleration" dialog or through the Python API (see https://perfetto.dev/docs/analysis/trace-processor#python-api).
# ./results/pixel/trace-three-camera-1-8
# [004.414]       http_server.cc:83 [HTTP] New connection
# [004.414]      http_server.cc:231 [HTTP] GET /status [body=0B, origin=""]
# [004.414]       http_server.cc:90 [HTTP] Client disconnected
# [004.418]       http_server.cc:83 [HTTP] New connection
# [004.418]      http_server.cc:231 [HTTP] POST /parse [body=104335B, origin=""]
# [004.423]      http_server.cc:231 [HTTP] GET /notify_eof [body=0B, origin=""]
# Loading trace 0.10 MB (0.0 MB/s)
# [004.437]      http_server.cc:231 [HTTP] POST /query [body=116B, origin=""]
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# [004.530]             httpd.cc:99 [HTTP] Starting RPC server on localhost:49474
# [004.530]            httpd.cc:104 [HTTP] This server can be used by reloading https://ui.perfetto.dev and clicking on YES on the "Trace Processor native acceleration" dialog or through the Python API (see https://perfetto.dev/docs/analysis/trace-processor#python-api).
# ./results/pixel/trace-three-camera-1-64
# [005.495]       http_server.cc:83 [HTTP] New connection
# [005.496]      http_server.cc:231 [HTTP] GET /status [body=0B, origin=""]
# [005.496]       http_server.cc:90 [HTTP] Client disconnected
# [005.498]       http_server.cc:83 [HTTP] New connection
# [005.498]      http_server.cc:231 [HTTP] POST /parse [body=104414B, origin=""]
# [005.501]      http_server.cc:231 [HTTP] GET /notify_eof [body=0B, origin=""]
# Loading trace 0.10 MB (0.0 MB/s)
# [005.508]      http_server.cc:231 [HTTP] POST /query [body=116B, origin=""]
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# [131.819]             httpd.cc:99 [HTTP] Starting RPC server on localhost:51606
# [131.819]            httpd.cc:104 [HTTP] This server can be used by reloading https://ui.perfetto.dev and clicking on YES on the "Trace Processor native acceleration" dialog or through the Python API (see https://perfetto.dev/docs/analysis/trace-processor#python-api).
# ./results/pixel/trace-mindar-aframe-camera-2-64
# [132.787]       http_server.cc:83 [HTTP] New connection
# [132.787]      http_server.cc:231 [HTTP] GET /status [body=0B, origin=""]
# [132.787]       http_server.cc:90 [HTTP] Client disconnected
# [132.791]       http_server.cc:83 [HTTP] New connection
# [132.792]      http_server.cc:231 [HTTP] POST /parse [body=106000B, origin=""]
# [132.798]      http_server.cc:231 [HTTP] GET /notify_eof [body=0B, origin=""]
# Loading trace 0.11 MB (0.0 MB/s)
# [132.811]      http_server.cc:231 [HTTP] POST /query [body=116B, origin=""]
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# [132.904]             httpd.cc:99 [HTTP] Starting RPC server on localhost:51623
# [132.904]            httpd.cc:104 [HTTP] This server can be used by reloading https://ui.perfetto.dev and clicking on YES on the "Trace Processor native acceleration" dialog or through the Python API (see https://perfetto.dev/docs/analysis/trace-processor#python-api).
# ./results/pixel/trace-mindar-aframe-camera-2-512
# ./results/pixel/trace-mindar-aframe-camera-2-4096
# ./results/pixel/trace-mindar-aframe-camera-2-32768
# ./results/pixel/trace-mindar-aframe-camera-4-8
# ./results/pixel/trace-mindar-aframe-camera-4-64
# ./results/pixel/trace-mindar-aframe-camera-4-512
# ./results/pixel/trace-mindar-aframe-camera-4-4096
# ./results/pixel/trace-mindar-aframe-camera-4-32768
# [133.872]       http_server.cc:83 [HTTP] New connection
# [133.872]      http_server.cc:231 [HTTP] GET /status [body=0B, origin=""]
# [133.872]       http_server.cc:90 [HTTP] Client disconnected
# [133.876]       http_server.cc:83 [HTTP] New connection
# [133.876]      http_server.cc:231 [HTTP] POST /parse [body=105794B, origin=""]
# [133.882]      http_server.cc:231 [HTTP] GET /notify_eof [body=0B, origin=""]
# Loading trace 0.11 MB (0.0 MB/s)
# [133.895]      http_server.cc:231 [HTTP] POST /query [body=116B, origin=""]
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_72373/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
