# %%
import pandas as pd
import os
from perfetto.trace_processor import TraceProcessor, TraceProcessorConfig
import matplotlib.pyplot as plt

# %%
frameworks = ['three','babylon','playcanvas','aframe','rtf','ar-three','ar-aframe','mindar-three','mindar-aframe']
cubeNums = [8,64,512,4096,32768]
textureNums =[0,1,2,4]
railNames = ['power.rails.aoc.logic',
            'power.rails.aoc.memory',
            'power.rails.cpu.big',
            'power.rails.cpu.little',
            'power.rails.cpu.mid',
            'power.rails.ddr.a',
            'power.rails.ddr.b',
            'power.rails.ddr.c',
            'power.rails.display',
            'power.rails.gpu',
            'power.rails.memory.interface',
            'power.rails.modem',
            'power.rails.radio.frontend',
            'power.rails.system.fabric',
            'power.rails.tpu',
            'power.rails.wifi.bt']

# %%
def getEnergy(filename):
    config = TraceProcessorConfig(verbose=True,bin_path='./trace_processor')
    tp = TraceProcessor(trace=filename,config=config)
    qr_it = tp.query('select ts, counter_track.name, value  from counter left join counter_track where counter_track.id=counter.track_id')
    qr_df = qr_it.as_pandas_dataframe()
    power_df = qr_df[qr_df['name'].str[:5] == 'power']
    power_df = power_df.drop_duplicates()
    total_mean_ratio = 0
    name_mean_ratio = {}
    for i, name in enumerate(railNames):
        data = power_df[power_df['name'] == name]
        diffs = data['value'].diff()
        time_diffs = data['ts'].diff()
        data['ratio'] =  diffs / time_diffs*1000
        data = data.dropna()
        mean_ratio = data['ratio'].mean()
        name_mean_ratio[name] = mean_ratio
        total_mean_ratio += mean_ratio
    name_mean_ratio['total'] = total_mean_ratio
    return name_mean_ratio

# %%
with open ('./results/pixel-rendering-energy.csv','w') as f:
    f.write('framework,textureNum,cubeNum,total')
    for rail in railNames:
        f.write(','+rail)
    f.write('\n')
    for framework in frameworks:
        for textureNum in textureNums:
            for cubeNum in cubeNums:
                filename = './results/pixel/trace-'+framework+'-'+str(textureNum)+'-'+str(cubeNum)
                print(filename)
                if not os.path.exists(filename):
                    continue
                energyData = getEnergy(filename)
                f.write(framework+','+str(textureNum)+','+str(cubeNum)+','+str(energyData['total']))
                for rail in railNames:
                    f.write(','+str(energyData[rail]))
                f.write('\n')
# Out:
# ./results/pixel/trace-three-0-8
# [762.147]             httpd.cc:99 [HTTP] Starting RPC server on localhost:62155
# [762.147]            httpd.cc:104 [HTTP] This server can be used by reloading https://ui.perfetto.dev and clicking on YES on the "Trace Processor native acceleration" dialog or through the Python API (see https://perfetto.dev/docs/analysis/trace-processor#python-api).
# [763.087]       http_server.cc:83 [HTTP] New connection
# [763.088]      http_server.cc:231 [HTTP] GET /status [body=0B, origin=""]
# [763.088]       http_server.cc:90 [HTTP] Client disconnected
# [763.090]       http_server.cc:83 [HTTP] New connection
# [763.090]      http_server.cc:231 [HTTP] POST /parse [body=104589B, origin=""]
# [763.093]      http_server.cc:231 [HTTP] GET /notify_eof [body=0B, origin=""]
# Loading trace 0.10 MB (0.0 MB/s)
# [763.099]      http_server.cc:231 [HTTP] POST /query [body=116B, origin=""]
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# [763.178]             httpd.cc:99 [HTTP] Starting RPC server on localhost:62172
# [763.178]            httpd.cc:104 [HTTP] This server can be used by reloading https://ui.perfetto.dev and clicking on YES on the "Trace Processor native acceleration" dialog or through the Python API (see https://perfetto.dev/docs/analysis/trace-processor#python-api).
# ./results/pixel/trace-three-0-64
# [764.145]       http_server.cc:83 [HTTP] New connection
# [764.145]      http_server.cc:231 [HTTP] GET /status [body=0B, origin=""]
# [764.145]       http_server.cc:90 [HTTP] Client disconnected
# [764.148]       http_server.cc:83 [HTTP] New connection
# [764.148]      http_server.cc:231 [HTTP] POST /parse [body=104464B, origin=""]
# [764.153]      http_server.cc:231 [HTTP] GET /notify_eof [body=0B, origin=""]
# Loading trace 0.10 MB (0.0 MB/s)
# [764.163]      http_server.cc:231 [HTTP] POST /query [body=116B, origin=""]
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# [764.250]             httpd.cc:99 [HTTP] Starting RPC server on localhost:62189
# [764.250]            httpd.cc:104 [HTTP] This server can be used by reloading https://ui.perfetto.dev and clicking on YES on the "Trace Processor native acceleration" dialog or through the Python API (see https://perfetto.dev/docs/analysis/trace-processor#python-api).
# ./results/pixel/trace-three-0-512
# [765.218]       http_server.cc:83 [HTTP] New connection
# [765.219]      http_server.cc:231 [HTTP] GET /status [body=0B, origin=""]
# [765.219]       http_server.cc:90 [HTTP] Client disconnected
# [765.222]       http_server.cc:83 [HTTP] New connection
# [765.222]      http_server.cc:231 [HTTP] POST /parse [body=104447B, origin=""]
# [765.227]      http_server.cc:231 [HTTP] GET /notify_eof [body=0B, origin=""]
# Loading trace 0.10 MB (0.0 MB/s)
# [765.239]      http_server.cc:231 [HTTP] POST /query [body=116B, origin=""]
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# [765.330]             httpd.cc:99 [HTTP] Starting RPC server on localhost:62206
# [765.330]            httpd.cc:104 [HTTP] This server can be used by reloading https://ui.perfetto.dev and clicking on YES on the "Trace Processor native acceleration" dialog or through the Python API (see https://perfetto.dev/docs/analysis/trace-processor#python-api).
# ./results/pixel/trace-three-0-4096
# [766.299]       http_server.cc:83 [HTTP] New connection
# [766.299]      http_server.cc:231 [HTTP] GET /status [body=0B, origin=""]
# [766.299]       http_server.cc:90 [HTTP] Client disconnected
# [766.303]       http_server.cc:83 [HTTP] New connection
# [766.304]      http_server.cc:231 [HTTP] POST /parse [body=104679B, origin=""]
# [766.310]      http_server.cc:231 [HTTP] GET /notify_eof [body=0B, origin=""]
# Loading trace 0.10 MB (0.0 MB/s)
# [766.324]      http_server.cc:231 [HTTP] POST /query [body=116B, origin=""]
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# [766.418]             httpd.cc:99 [HTTP] Starting RPC server on localhost:62234
# [766.418]            httpd.cc:104 [HTTP] This server can be used by reloading https://ui.perfetto.dev and clicking on YES on the "Trace Processor native acceleration" dialog or through the Python API (see https://perfetto.dev/docs/analysis/trace-processor#python-api).
# ./results/pixel/trace-three-0-32768
# [767.386]       http_server.cc:83 [HTTP] New connection
# [767.386]      http_server.cc:231 [HTTP] GET /status [body=0B, origin=""]
# [767.387]       http_server.cc:90 [HTTP] Client disconnected
# [767.392]       http_server.cc:83 [HTTP] New connection
# [767.392]      http_server.cc:231 [HTTP] POST /parse [body=104392B, origin=""]
# [767.398]      http_server.cc:231 [HTTP] GET /notify_eof [body=0B, origin=""]
# Loading trace 0.10 MB (0.0 MB/s)
# [767.412]      http_server.cc:231 [HTTP] POST /query [body=116B, origin=""]
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# [767.504]             httpd.cc:99 [HTTP] Starting RPC server on localhost:62251
# [767.504]            httpd.cc:104 [HTTP] This server can be used by reloading https://ui.perfetto.dev and clicking on YES on the "Trace Processor native acceleration" dialog or through the Python API (see https://perfetto.dev/docs/analysis/trace-processor#python-api).
# ./results/pixel/trace-three-1-8
# [768.473]       http_server.cc:83 [HTTP] New connection
# [768.473]      http_server.cc:231 [HTTP] GET /status [body=0B, origin=""]
# [768.473]       http_server.cc:90 [HTTP] Client disconnected
# [768.478]       http_server.cc:83 [HTTP] New connection
# [768.479]      http_server.cc:231 [HTTP] POST /parse [body=104487B, origin=""]
# [768.485]      http_server.cc:231 [HTTP] GET /notify_eof [body=0B, origin=""]
# Loading trace 0.10 MB (0.0 MB/s)
# [768.498]      http_server.cc:231 [HTTP] POST /query [body=116B, origin=""]
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# [768.591]             httpd.cc:99 [HTTP] Starting RPC server on localhost:62268
# [768.591]            httpd.cc:104 [HTTP] This server can be used by reloading https://ui.perfetto.dev and clicking on YES on the "Trace Processor native acceleration" dialog or through the Python API (see https://perfetto.dev/docs/analysis/trace-processor#python-api).
# ./results/pixel/trace-three-1-64
# [769.560]       http_server.cc:83 [HTTP] New connection
# [769.560]      http_server.cc:231 [HTTP] GET /status [body=0B, origin=""]
# [769.561]       http_server.cc:90 [HTTP] Client disconnected
# [769.567]       http_server.cc:83 [HTTP] New connection
# [769.567]      http_server.cc:231 [HTTP] POST /parse [body=104471B, origin=""]
# [769.573]      http_server.cc:231 [HTTP] GET /notify_eof [body=0B, origin=""]
# Loading trace 0.10 MB (0.0 MB/s)
# [769.585]      http_server.cc:231 [HTTP] POST /query [body=116B, origin=""]
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# [918.722]             httpd.cc:99 [HTTP] Starting RPC server on localhost:64821
# [918.722]            httpd.cc:104 [HTTP] This server can be used by reloading https://ui.perfetto.dev and clicking on YES on the "Trace Processor native acceleration" dialog or through the Python API (see https://perfetto.dev/docs/analysis/trace-processor#python-api).
# ./results/pixel/trace-mindar-aframe-2-64
# [919.690]       http_server.cc:83 [HTTP] New connection
# [919.690]      http_server.cc:231 [HTTP] GET /status [body=0B, origin=""]
# [919.690]       http_server.cc:90 [HTTP] Client disconnected
# [919.695]       http_server.cc:83 [HTTP] New connection
# [919.695]      http_server.cc:231 [HTTP] POST /parse [body=105945B, origin=""]
# [919.701]      http_server.cc:231 [HTTP] GET /notify_eof [body=0B, origin=""]
# Loading trace 0.11 MB (0.0 MB/s)
# [919.714]      http_server.cc:231 [HTTP] POST /query [body=116B, origin=""]
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# [919.809]             httpd.cc:99 [HTTP] Starting RPC server on localhost:64839
# [919.809]            httpd.cc:104 [HTTP] This server can be used by reloading https://ui.perfetto.dev and clicking on YES on the "Trace Processor native acceleration" dialog or through the Python API (see https://perfetto.dev/docs/analysis/trace-processor#python-api).
# ./results/pixel/trace-mindar-aframe-2-512
# ./results/pixel/trace-mindar-aframe-2-4096
# ./results/pixel/trace-mindar-aframe-2-32768
# ./results/pixel/trace-mindar-aframe-4-8
# ./results/pixel/trace-mindar-aframe-4-64
# ./results/pixel/trace-mindar-aframe-4-512
# ./results/pixel/trace-mindar-aframe-4-4096
# ./results/pixel/trace-mindar-aframe-4-32768
# [920.778]       http_server.cc:83 [HTTP] New connection
# [920.778]      http_server.cc:231 [HTTP] GET /status [body=0B, origin=""]
# [920.778]       http_server.cc:90 [HTTP] Client disconnected
# [920.783]       http_server.cc:83 [HTTP] New connection
# [920.783]      http_server.cc:231 [HTTP] POST /parse [body=105785B, origin=""]
# [920.789]      http_server.cc:231 [HTTP] GET /notify_eof [body=0B, origin=""]
# Loading trace 0.11 MB (0.0 MB/s)
# [920.802]      http_server.cc:231 [HTTP] POST /query [body=116B, origin=""]
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
# /var/folders/xk/5bd8h9y930n1m1vlv1v2r_wc0000gn/T/ipykernel_71666/3823898975.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ratio'] =  diffs / time_diffs*1000
